# %% [markdown]
# **openpyxl**:
#
# Назначение: openpyxl — это библиотека для работы с Excel-файлами на низком уровне. Она позволяет тебе читать и записывать Excel-файлы, включая форматирование, стили, формулы и другие свойства Excel.
#
# Чтение/Запись Excel: openpyxl дает более гибкий контроль над структурой и стилем Excel-файлов. Ты можешь работать непосредственно с ячейками, строками, столбцами, стилями, формулами, изображениями и т.д.
#
# Обработка данных: openpyxl не предназначена для анализа данных, как pandas. Ты можешь читать данные из ячеек, но для их агрегации, фильтрации и других сложных операций тебе придется писать много кода, так как openpyxl, это просто библиотека для работы с Excel файлами, а не библиотека для обработки данных.
#
# Форматирование: openpyxl предоставляет мощные инструменты для форматирования Excel-файлов, такие как:
#
# Изменение шрифтов, цветов, границ.
#
# Объединение ячеек, добавление изображений.
#
# Установка форматов чисел, дат.
#
# Работа с формулами.
#
#
#
# **Когда использовать openpyxl**:
#
# Когда тебе нужно создать Excel-файл с определенным форматированием или стилями.
#
# Когда тебе нужно более гибко управлять структурой Excel-файла.
#
# Когда тебе нужно прочитать данные из Excel-файла и, при этом, сохранить форматирование.
#
# Когда тебе нужно работать с формулами, изображениями или другими сложными элементами Excel-файла.
#
# **Краткое сравнение**:
#
# Основное назначение	Анализ и обработка данных	Работа с Excel-файлами на низком уровне
# Работа с данными	DataFrame, мощные инструменты	Чтение и запись ячеек
# Форматирование	Ограниченные возможности	Гибкий контроль над форматированием
# Сложность	Простой и удобный интерфейс	Более сложный API
# Производительность	Высокая, при работе с данными	Ниже, при работе с большим количеством данных
#
# **Пример**:
#
# pandas: Ты можешь использовать pandas для загрузки данных о продажах из Excel-файла, расчета общей прибыли и визуализации данных.
#
# openpyxl: Ты можешь использовать openpyxl для создания шаблона Excel-файла с логотипом компании, формулами для расчета и нужным форматированием для отправки отчетов.

# %%
import openpyxl
import pandas as pd
import os

# %% [markdown]
# Этот код открывает файл tab.xlsx, находит первый лист, затем проходит по ячейкам в столбце 3 (столбце С) строк с 7 по 27 и находит наименьшее значение в этих ячейках.

# %%
wb = openpyxl.load_workbook('tab.xlsx')
sheet_names = wb.sheetnames # Возвращает список (list) строк, содержащих имена всех листов (sheets) в рабочей книге wb
sh = wb[sheet_names[0]]  # Получаем первый элемент из списка имен листов (то есть имя первого листа).
nmin = sh.cell(row=7, column=3).value # Возвращаем объект, представляющий ячейку на листе sh в строке 7 и столбце 3
for rownum in range(8, 28):
    temp = sh.cell(row=rownum, column=3).value
    nmin = min(nmin, temp)
print(nmin)
# Out:
# 39650.2

# %% [markdown]
# Вася планирует карьеру и переезд. Для это составил таблицу, в которой для каждого региона записал зарплаты для разных интересные ему профессий. Таблица доступна по ссылке https://stepik.org/media/attachments/lesson/245267/salaries.xlsx. Выведите название региона с самой высокой медианной зарплатой (медианой называется элемент, стоящий в середине массива после его упорядочивания) и, через пробел, название профессии с самой высокой средней зарплатой по всем регионам.

# %%
wb = openpyxl.load_workbook('salaries.xlsx')

# %%
sheet_names = wb.sheetnames
sheet_names
# Out:
# ['Лист1']

# %%
sh = wb[sheet_names[0]]
sh
# Out:
# <Worksheet "Лист1">

# %%
sh.max_row
# Out:
# 9

# %%
sh.max_column
# Out:
# 8

# %%
colums = []
for column in range(1, sh.max_column + 1):
    colums.append(sh.cell(row=1, column=column).value)

colums
# Out:
# [None,
#  'Программист',
#  'Менеджер по клинингу',
#  'Дизайнер онлайн-курсов',
#  'Собачий парикмахер',
#  'Учитель для нейросетей',
#  'Сотрудник конной милиции',
#  'Актёр на роль человека-бутерброда']

# %%
rows = []
for row in range(1, sh.max_row + 1):
    rows.append(sh.cell(row=row, column=1).value)

rows
# Out:
# [None,
#  'Москва',
#  'Улан-Батор',
#  'Посёлок гидроузла имени Куйбышева',
#  'Крёкшино',
#  'Станица Юго-Северная',
#  'Куала-Лумпур',
#  'Хабнарфьордюр ',
#  'Ытык-Кюёль']

# %%
data = pd.DataFrame(index=rows[1:], columns=colums[1:])

for row in range(2, sh.max_row + 1):
    for column in range(2, sh.max_column + 1):
        data.loc[rows[row-1],colums[column-1]] = sh.cell(row=row, column=column).value
data
# Out:
#                                   Программист Менеджер по клинингу  \
# Москва                                    765                 9876
# Улан-Батор                                 87                87698
# Посёлок гидроузла имени Куйбышева      987595                   87
# Крёкшино                                 9876                 8769
# Станица Юго-Северная                     8769               987687
# Куала-Лумпур                           189710                  787
# Хабнарфьордюр                              65                76796
# Ытык-Кюёль                                769               786578
#
#                                   Дизайнер онлайн-курсов Собачий парикмахер  \
# Москва                                            546585                  6
# Улан-Батор                                          7698             965765
# Посёлок гидроузла имени Куйбышева                      5               7676
# Крёкшино                                            9859             897698
# Станица Юго-Северная                                  23               1212
# Куала-Лумпур                                      765679               9769
# Хабнарфьордюр                                        807             765685
# Ытык-Кюёль                                          1368              59625
#
#                                   Учитель для нейросетей  \
# Москва                                             65876
# Улан-Батор                                           769
# Посёлок гидроузла имени Куйбышева                   8765
# Крёкшино                                               7
# Станица Юго-Северная                                9876
# Куала-Лумпур                                       57686
# Хабнарфьордюр                                      97659
# Ытык-Кюёль                                          6758
#
#                                   Сотрудник конной милиции  \
# Москва                                                 765
# Улан-Батор                                             659
# Посёлок гидроузла имени Куйбышева                        9
# Крёкшино                                                69
# Станица Юго-Северная                                 23871
# Куала-Лумпур                                        769829
# Хабнарфьордюр                                        56913
# Ытык-Кюёль                                           76587
#
#                                   Актёр на роль человека-бутерброда
# Москва                                                          213
# Улан-Батор                                                    21523
# Посёлок гидроузла имени Куйбышева                              4356
# Крёкшино                                                        342
# Станица Юго-Северная                                           3224
# Куала-Лумпур                                                  53632
# Хабнарфьордюр                                                    32
# Ытык-Кюёль                                                     3453

# %%
data = pd.read_excel('salaries.xlsx', index_col=0)
data
# Out:
#                                    Программист  Менеджер по клинингу  \
# Москва                                     765                  9876
# Улан-Батор                                  87                 87698
# Посёлок гидроузла имени Куйбышева       987595                    87
# Крёкшино                                  9876                  8769
# Станица Юго-Северная                      8769                987687
# Куала-Лумпур                            189710                   787
# Хабнарфьордюр                               65                 76796
# Ытык-Кюёль                                 769                786578
#
#                                    Дизайнер онлайн-курсов  Собачий парикмахер  \
# Москва                                             546585                   6
# Улан-Батор                                           7698              965765
# Посёлок гидроузла имени Куйбышева                       5                7676
# Крёкшино                                             9859              897698
# Станица Юго-Северная                                   23                1212
# Куала-Лумпур                                       765679                9769
# Хабнарфьордюр                                         807              765685
# Ытык-Кюёль                                           1368               59625
#
#                                    Учитель для нейросетей  \
# Москва                                              65876
# Улан-Батор                                            769
# Посёлок гидроузла имени Куйбышева                    8765
# Крёкшино                                                7
# Станица Юго-Северная                                 9876
# Куала-Лумпур                                        57686
# Хабнарфьордюр                                       97659
# Ытык-Кюёль                                           6758
#
#                                    Сотрудник конной милиции  \
# Москва                                                  765
# Улан-Батор                                              659
# Посёлок гидроузла имени Куйбышева                         9
# Крёкшино                                                 69
# Станица Юго-Северная                                  23871
# Куала-Лумпур                                         769829
# Хабнарфьордюр                                         56913
# Ытык-Кюёль                                            76587
#
#                                    Актёр на роль человека-бутерброда
# Москва                                                           213
# Улан-Батор                                                     21523
# Посёлок гидроузла имени Куйбышева                               4356
# Крёкшино                                                         342
# Станица Юго-Северная                                            3224
# Куала-Лумпур                                                   53632
# Хабнарфьордюр                                                     32
# Ытык-Кюёль                                                      3453

# %%
data.mean().sort_values(ascending=False).index[0]
# Out:
# 'Собачий парикмахер'

# %%
data.mean().idxmax()
# Out:
# 'Собачий парикмахер'

# %%
data.transpose().median().idxmax()
# Out:
# 'Куала-Лумпур'

# %% [markdown]
# Васю назначили завхозом в туристической группе и он подошёл к подготовке ответственно, составив справочник продуктов с указанием калорийности на 100 грамм, а также содержание белков, жиров и углеводов на 100 грамм продукта. Ему не удалось найти всю информацию, поэтому некоторые ячейки остались незаполненными (можно считать их значение равным нулю). Также он использовал какой-то странный офисный пакет и разделял целую и дробную часть чисел запятой. Таблица доступна по ссылке https://stepik.org/media/attachments/lesson/245290/trekking1.xlsx
#
# Вася хочет минимизировать вес продуктов и для этого брать самые калорийные продукты. Помогите ему и упорядочите продукты по убыванию калорийности. В случае, если продукты имеют одинаковую калорийность - упорядочите их по названию. В качестве ответа необходимо сдать названия продуктов, по одному в строке.

# %%
data = pd.read_excel('trekking1.xlsx').fillna(0)
data.rename({data.columns[0]: 'Продукт'}, axis=1, inplace=True)
data
# Out:
#                                   Продукт  ККал на 100  Б на 100  Ж на 100  \
# 0                              Сухофрукты        548.0      12.8      40.8
# 1                            Каша Быстров        334.0       8.6       4.8
# 2                     Балык "Королевский"        170.0      25.0       8.0
# 3       Колбаса с/к "Еврейская полусухая"        481.0      19.0      45.0
# 4            Суп гороховый с копченостями        390.0      16.0      11.0
# 5                    Суп томатный с рисом        205.5       4.7       1.3
# 6                       Говядина Кронидов        213.0      15.0      17.0
# 7                        Свинина Кронидов        349.0      13.0      33.0
# 8                  Рис пропаренный Увелка        350.0       8.0       1.0
# 9                         Крупа гречневая        360.0      13.0       2.0
# 10                        Капеллини Макфа        344.0      12.5       1.3
# 11             Сухарики ржаные Finn Crisp        347.0      10.0       2.6
# 12                     Козинак арахисовый        520.0      15.0      26.0
# 13                   Козинак подсолнечный        530.0      14.0      37.0
# 14                 Шоколад молочный какао        601.0       7.0      43.0
# 15               Шоколад молочный миндаль        574.0       7.7      38.2
# 16                    Шоколад ремесленный        540.0      10.8      37.8
# 17                            Сыр Маасдам        370.0      25.0      30.0
# 18                              Сыр Гауда        338.0      26.0      26.0
# 19                             Сыр Чеддер        369.0      23.5      30.5
# 20            Сухарики ржаные с семечками        451.0      17.3      16.0
# 21               Хлебцы льняные "Тайские"        507.0      19.0      39.0
# 22                 Хлебцы льняные Морские        436.5      14.1      29.0
# 23                                Паутина         12.0       0.0       0.0
# 24              Хлебцы с чесноком и луком        212.0       7.9       1.3
# 25                Говядина сублимрованная        474.0      73.0      20.0
# 26                 Свинина сублимрованная        543.0      58.0      35.0
# 27               Борщ Московский Галагала        360.0      15.0      10.0
# 28                     Суп-гуляш галагала        382.0      15.0      10.0
# 29      Суп куриный с картофелем галагала        390.0      15.0      12.0
# 30      Суп говяжий с картофелем галагала        390.0      12.2      12.0
# 31  Суп гороховый с копченостями галагала        390.0      16.0      11.0
# 32                     Суп-харчо "Острый"        370.0      13.5      10.0
# 33                      Картофель сушеный        333.0       6.0      74.0
# 34               Омлет с грибами галагала        526.0      43.0      30.0
# 35          Омлет с копченостями галагала        544.0      45.0      30.0
# 36                                Кус Кус        336.0      12.7       0.6
#
#     У на 100
# 0       32.4
# 1       64.0
# 2        0.0
# 3        0.0
# 4       52.0
# 5       42.2
# 6        0.0
# 7        0.0
# 8       78.0
# 9       72.0
# 10      70.5
# 11      61.0
# 12      55.0
# 13      36.0
# 14      46.0
# 15      49.5
# 16      37.1
# 17       0.0
# 18       0.0
# 19       0.0
# 20      59.5
# 21      20.0
# 22       1.5
# 23       0.0
# 24      43.3
# 25       0.0
# 26       0.0
# 27      52.0
# 28      55.0
# 29      56.4
# 30      56.4
# 31      52.0
# 32      55.6
# 33       0.0
# 34       4.7
# 35       4.7
# 36      77.4

# %%
list_products = data.sort_values(by=['ККал на 100', 'Продукт'], ascending=[False, True])['Продукт'].to_list()
for i in list_products:
    print(i)
# Out:
# Шоколад молочный какао
# Шоколад молочный миндаль
# Сухофрукты
# Омлет с копченостями галагала
# Свинина сублимрованная
# Шоколад ремесленный
# Козинак подсолнечный
# Омлет с грибами галагала
# Козинак арахисовый
# Хлебцы льняные "Тайские"
# Колбаса с/к "Еврейская полусухая"
# Говядина сублимрованная
# Сухарики ржаные с семечками
# Хлебцы льняные Морские
# Суп говяжий с картофелем галагала
# Суп гороховый с копченостями
# Суп гороховый с копченостями галагала
# Суп куриный с картофелем галагала
# Суп-гуляш галагала
# Суп-харчо "Острый"
# Сыр Маасдам
# Сыр Чеддер
# Борщ Московский Галагала
# Крупа гречневая
# Рис пропаренный Увелка
# Свинина Кронидов
# Сухарики ржаные Finn Crisp
# Капеллини Макфа
# Сыр Гауда
# Кус Кус
# Каша Быстров
# Картофель сушеный
# Говядина Кронидов
# Хлебцы с чесноком и луком
# Суп томатный с рисом
# Балык "Королевский"
# Паутина

# %% [markdown]
# Васю назначили завхозом в туристической группе и он подошёл к подготовке ответственно, составив справочник продуктов с указанием калорийности на 100 грамм, а также содержание белков, жиров и углеводов на 100 грамм продукта. Ему не удалось найти всю информацию, поэтому некоторые ячейки остались незаполненными (можно считать их значение равным нулю). Также он использовал какой-то странный офисный пакет и разделял целую и дробную часть чисел запятой. Таблица доступна по ссылке https://stepik.org/media/attachments/lesson/245290/trekking2.xlsx
#
# Вася составил раскладку по продуктам на один день (она на листе "Раскладка") с указанием названия продукта и его количества в граммах. Посчитайте 4 числа: суммарную калорийность и граммы белков, жиров и углеводов. Числа округлите до целых вниз и введите через пробел.

# %%
wb = openpyxl.load_workbook('trekking2.xlsx')
sheet_names = wb.sheetnames
sheet_names
# Out:
# ['Справочник', 'Раскладка']

# %%
data_all_products = pd.read_excel('trekking2.xlsx', sheet_name=sheet_names[0])
data_products_someday = pd.read_excel('trekking2.xlsx', sheet_name=sheet_names[1])

# %%
data_all_products.rename({'Unnamed: 0': 'Продукт'}, axis=1, inplace=True)
data_all_products
# Out:
#                                   Продукт  ККал на 100  Б на 100  Ж на 100  \
# 0                              Сухофрукты        548.0      12.8      40.8
# 1                            Каша Быстров        334.0       8.6       4.8
# 2                     Балык "Королевский"        170.0      25.0       8.0
# 3       Колбаса с/к "Еврейская полусухая"        481.0      19.0      45.0
# 4            Суп гороховый с копченостями        390.0      16.0      11.0
# 5                    Суп томатный с рисом        205.5       4.7       1.3
# 6                       Говядина Кронидов        213.0      15.0      17.0
# 7                        Свинина Кронидов        349.0      13.0      33.0
# 8                  Рис пропаренный Увелка        350.0       8.0       1.0
# 9                         Крупа гречневая        360.0      13.0       2.0
# 10                        Капеллини Макфа        344.0      12.5       1.3
# 11             Сухарики ржаные Finn Crisp        347.0      10.0       2.6
# 12                     Козинак арахисовый        520.0      15.0      26.0
# 13                   Козинак подсолнечный        530.0      14.0      37.0
# 14                 Шоколад молочный какао        601.0       7.0      43.0
# 15               Шоколад молочный миндаль        574.0       7.7      38.2
# 16                    Шоколад ремесленный        540.0      10.8      37.8
# 17                            Сыр Маасдам        370.0      25.0      30.0
# 18                              Сыр Гауда        338.0      26.0      26.0
# 19                             Сыр Чеддер        369.0      23.5      30.5
# 20            Сухарики ржаные с семечками        451.0      17.3      16.0
# 21               Хлебцы льняные "Тайские"        507.0      19.0      39.0
# 22                 Хлебцы льняные Морские        436.5      14.1      29.0
# 23                                Паутина         12.0       NaN       NaN
# 24              Хлебцы с чесноком и луком        212.0       7.9       1.3
# 25                Говядина сублимрованная        474.0      73.0      20.0
# 26                 Свинина сублимрованная        543.0      58.0      35.0
# 27               Борщ Московский Галагала        360.0      15.0      10.0
# 28                     Суп-гуляш галагала        382.0      15.0      10.0
# 29      Суп куриный с картофелем галагала        390.0      15.0      12.0
# 30      Суп говяжий с картофелем галагала        390.0      12.2      12.0
# 31  Суп гороховый с копченостями галагала        390.0      16.0      11.0
# 32                     Суп-харчо "Острый"        370.0      13.5      10.0
# 33                      Картофель сушеный        333.0       6.0      74.0
# 34               Омлет с грибами галагала        526.0      43.0      30.0
# 35          Омлет с копченостями галагала        544.0      45.0      30.0
# 36                                Кус Кус        336.0      12.7       0.6
#
#     У на 100
# 0       32.4
# 1       64.0
# 2        NaN
# 3        NaN
# 4       52.0
# 5       42.2
# 6        NaN
# 7        NaN
# 8       78.0
# 9       72.0
# 10      70.5
# 11      61.0
# 12      55.0
# 13      36.0
# 14      46.0
# 15      49.5
# 16      37.1
# 17       NaN
# 18       NaN
# 19       NaN
# 20      59.5
# 21      20.0
# 22       1.5
# 23       NaN
# 24      43.3
# 25       NaN
# 26       NaN
# 27      52.0
# 28      55.0
# 29      56.4
# 30      56.4
# 31      52.0
# 32      55.6
# 33       NaN
# 34       4.7
# 35       4.7
# 36      77.4

# %%
data_products_someday
# Out:
#                               Продукт  Вес в граммах
# 0            Омлет с грибами галагала             60
# 1                         Сыр Маасдам             80
# 2              Хлебцы льняные Морские             55
# 3        Суп гороховый с копченостями             44
# 4              Хлебцы льняные Морские             55
# 5   Колбаса с/к "Еврейская полусухая"             80
# 6                   Говядина Кронидов            250
# 7                     Крупа гречневая            160
# 8         Сухарики ржаные с семечками            120
# 9   Колбаса с/к "Еврейская полусухая"             80
# 10                         Сухофрукты            150
# 11           Шоколад молочный миндаль             80

# %%
data_merge = data_products_someday.merge(data_all_products, how='left', on='Продукт').fillna(0)
data_merge
# Out:
#                               Продукт  Вес в граммах  ККал на 100  Б на 100  \
# 0            Омлет с грибами галагала             60        526.0      43.0
# 1                         Сыр Маасдам             80        370.0      25.0
# 2              Хлебцы льняные Морские             55        436.5      14.1
# 3        Суп гороховый с копченостями             44        390.0      16.0
# 4              Хлебцы льняные Морские             55        436.5      14.1
# 5   Колбаса с/к "Еврейская полусухая"             80        481.0      19.0
# 6                   Говядина Кронидов            250        213.0      15.0
# 7                     Крупа гречневая            160        360.0      13.0
# 8         Сухарики ржаные с семечками            120        451.0      17.3
# 9   Колбаса с/к "Еврейская полусухая"             80        481.0      19.0
# 10                         Сухофрукты            150        548.0      12.8
# 11           Шоколад молочный миндаль             80        574.0       7.7
#
#     Ж на 100  У на 100
# 0       30.0       4.7
# 1       30.0       0.0
# 2       29.0       1.5
# 3       11.0      52.0
# 4       29.0       1.5
# 5       45.0       0.0
# 6       17.0       0.0
# 7        2.0      72.0
# 8       16.0      59.5
# 9       45.0       0.0
# 10      40.8      32.4
# 11      38.2      49.5

# %%
products_dict = {k: 0 for k in data_merge.columns[2:]}

print(products_dict)

for index, row in data_merge.iterrows():
    weight = row['Вес в граммах'] / 100
    for nutrient in products_dict:
       products_dict[nutrient] += weight * row[nutrient]
# Out:
# {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0}

# %%
result = list(map(int, products_dict.values()))
result
# Out:
# [4963, 203, 307, 302]

# %% [markdown]
# Васю назначили завхозом в туристической группе и он подошёл к подготовке ответственно, составив справочник продуктов с указанием калорийности на 100 грамм, а также содержание белков, жиров и углеводов на 100 грамм продукта. Ему не удалось найти всю информацию, поэтому некоторые ячейки остались незаполненными (можно считать их значение равным нулю). Также он использовал какой-то странный офисный пакет и разделял целую и дробную часть чисел запятой. Таблица доступна по ссылке https://stepik.org/media/attachments/lesson/245290/trekking3.xlsx
#
# Вася составил раскладку по продуктам на весь поход (она на листе "Раскладка") с указанием номера дня, названия продукта и его количества в граммах. Для каждого дня посчитайте 4 числа: суммарную калорийность и граммы белков, жиров и углеводов. Числа округлите до целых вниз и введите через пробел. Информация о каждом дне должна выводиться в отдельной строке.

# %%
excel_file = pd.ExcelFile('trekking3.xlsx')
sheet_names = excel_file.sheet_names
sheet_names
# Out:
# ['Справочник', 'Раскладка']

# %%
data_products_per_day = pd.read_excel('trekking3.xlsx', sheet_name='Раскладка')
data_products_per_day
# Out:
#     День                      Продукт  Вес в граммах
# 0      1       Рис пропаренный Увелка            160
# 1      1             Свинина Кронидов            250
# 2      1     Хлебцы льняные "Тайские"            110
# 3      1          Балык "Королевский"             50
# 4      1       Шоколад молочный какао             55
# ..   ...                          ...            ...
# 94     8       Шоколад молочный какао             55
# 95     9  Сухарики ржаные с семечками            120
# 96     9          Балык "Королевский"             80
# 97     9                   Сухофрукты            150
# 98     9                 Каша Быстров             80
#
# [99 rows x 3 columns]

# %%
data_all_products = pd.read_excel('trekking3.xlsx', sheet_name='Справочник').fillna(0).rename({'Unnamed: 0': 'Продукт'}, axis=1)
data_all_products
# Out:
#                                   Продукт  ККал на 100  Б на 100  Ж на 100  \
# 0                              Сухофрукты        548.0      12.8      40.8
# 1                            Каша Быстров        334.0       8.6       4.8
# 2                     Балык "Королевский"        170.0      25.0       8.0
# 3       Колбаса с/к "Еврейская полусухая"        481.0      19.0      45.0
# 4            Суп гороховый с копченостями        390.0      16.0      11.0
# 5                    Суп томатный с рисом        205.5       4.7       1.3
# 6                       Говядина Кронидов        213.0      15.0      17.0
# 7                        Свинина Кронидов        349.0      13.0      33.0
# 8                  Рис пропаренный Увелка        350.0       8.0       1.0
# 9                         Крупа гречневая        360.0      13.0       2.0
# 10                        Капеллини Макфа        344.0      12.5       1.3
# 11             Сухарики ржаные Finn Crisp        347.0      10.0       2.6
# 12                     Козинак арахисовый        520.0      15.0      26.0
# 13                   Козинак подсолнечный        530.0      14.0      37.0
# 14                 Шоколад молочный какао        601.0       7.0      43.0
# 15               Шоколад молочный миндаль        574.0       7.7      38.2
# 16                    Шоколад ремесленный        540.0      10.8      37.8
# 17                            Сыр Маасдам        370.0      25.0      30.0
# 18                              Сыр Гауда        338.0      26.0      26.0
# 19                             Сыр Чеддер        369.0      23.5      30.5
# 20            Сухарики ржаные с семечками        451.0      17.3      16.0
# 21               Хлебцы льняные "Тайские"        507.0      19.0      39.0
# 22                 Хлебцы льняные Морские        436.5      14.1      29.0
# 23                                Паутина         12.0       0.0       0.0
# 24              Хлебцы с чесноком и луком        212.0       7.9       1.3
# 25                Говядина сублимрованная        474.0      73.0      20.0
# 26                 Свинина сублимрованная        543.0      58.0      35.0
# 27               Борщ Московский Галагала        360.0      15.0      10.0
# 28                     Суп-гуляш галагала        382.0      15.0      10.0
# 29      Суп куриный с картофелем галагала        390.0      15.0      12.0
# 30      Суп говяжий с картофелем галагала        390.0      12.2      12.0
# 31  Суп гороховый с копченостями галагала        390.0      16.0      11.0
# 32                     Суп-харчо "Острый"        370.0      13.5      10.0
# 33                      Картофель сушеный        333.0       6.0      74.0
# 34               Омлет с грибами галагала        526.0      43.0      30.0
# 35          Омлет с копченостями галагала        544.0      45.0      30.0
# 36                                Кус Кус        336.0      12.7       0.6
#
#     У на 100
# 0       32.4
# 1       64.0
# 2        0.0
# 3        0.0
# 4       52.0
# 5       42.2
# 6        0.0
# 7        0.0
# 8       78.0
# 9       72.0
# 10      70.5
# 11      61.0
# 12      55.0
# 13      36.0
# 14      46.0
# 15      49.5
# 16      37.1
# 17       0.0
# 18       0.0
# 19       0.0
# 20      59.5
# 21      20.0
# 22       1.5
# 23       0.0
# 24      43.3
# 25       0.0
# 26       0.0
# 27      52.0
# 28      55.0
# 29      56.4
# 30      56.4
# 31      52.0
# 32      55.6
# 33       0.0
# 34       4.7
# 35       4.7
# 36      77.4

# %%
data_merge = data_products_per_day.merge(data_all_products, how='left', on='Продукт')
data_merge
# Out:
#     День                      Продукт  Вес в граммах  ККал на 100  Б на 100  \
# 0      1       Рис пропаренный Увелка            160        350.0       8.0
# 1      1             Свинина Кронидов            250        349.0      13.0
# 2      1     Хлебцы льняные "Тайские"            110        507.0      19.0
# 3      1          Балык "Королевский"             50        170.0      25.0
# 4      1       Шоколад молочный какао             55        601.0       7.0
# ..   ...                          ...            ...          ...       ...
# 94     8       Шоколад молочный какао             55        601.0       7.0
# 95     9  Сухарики ржаные с семечками            120        451.0      17.3
# 96     9          Балык "Королевский"             80        170.0      25.0
# 97     9                   Сухофрукты            150        548.0      12.8
# 98     9                 Каша Быстров             80        334.0       8.6
#
#     Ж на 100  У на 100
# 0        1.0      78.0
# 1       33.0       0.0
# 2       39.0      20.0
# 3        8.0       0.0
# 4       43.0      46.0
# ..       ...       ...
# 94      43.0      46.0
# 95      16.0      59.5
# 96       8.0       0.0
# 97      40.8      32.4
# 98       4.8      64.0
#
# [99 rows x 7 columns]

# %%
products_dict = dict()
for d in data_merge['День']:
    if d not in products_dict:
        products_dict[d] = dict()
    for i in data_merge.columns[3:]:
        if i not in products_dict[d]:
            products_dict[d][i] = 0
products_dict
# Out:
# {1: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  2: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  3: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  4: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  5: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  6: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  7: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  8: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0},
#  9: {'ККал на 100': 0, 'Б на 100': 0, 'Ж на 100': 0, 'У на 100': 0}}

# %%
for index, row in data_merge.iterrows():
    weight = row['Вес в граммах'] / 100
    day = row['День']
    for nutrient in products_dict[day]:
        products_dict[day][nutrient] += weight * row[nutrient]

products_dict
# Out:
# {1: {'ККал на 100': 2405.75,
#   'Б на 100': 82.55,
#   'Ж на 100': 154.65,
#   'У на 100': 172.10000000000002},
#  2: {'ККал на 100': 4963.849999999999,
#   'Б на 100': 203.17,
#   'Ж на 100': 307.4,
#   'У на 100': 302.15},
#  3: {'ККал на 100': 5219.7,
#   'Б на 100': 178.77,
#   'Ж на 100': 267.39,
#   'У на 100': 502.8140000000001},
#  4: {'ККал на 100': 4873.150000000001,
#   'Б на 100': 241.13799999999998,
#   'Ж на 100': 204.65,
#   'У на 100': 537.856},
#  5: {'ККал на 100': 5278.4,
#   'Б на 100': 243.44,
#   'Ж на 100': 314.68,
#   'У на 100': 367.41600000000005},
#  6: {'ККал на 100': 4451.7,
#   'Б на 100': 190.52999999999997,
#   'Ж на 100': 188.35000000000002,
#   'У на 100': 497.45},
#  7: {'ККал на 100': 4806.599999999999,
#   'Б на 100': 205.838,
#   'Ж на 100': 265.83,
#   'У на 100': 386.586},
#  8: {'ККал на 100': 5738.750000000001,
#   'Б на 100': 264.93,
#   'Ж на 100': 195.39,
#   'У на 100': 720.13},
#  9: {'ККал на 100': 1766.3999999999999,
#   'Б на 100': 66.84,
#   'Ж на 100': 90.64,
#   'У на 100': 171.2}}

# %%
for v in products_dict.values():
    for a, b in v.items():
        print(int(b), end=' ')
    print()
# Out:
# 2405 82 154 172
# 4963 203 307 302
# 5219 178 267 502
# 4873 241 204 537
# 5278 243 314 367
# 4451 190 188 497
# 4806 205 265 386
# 5738 264 195 720
# 1766 66 90 171

# %% [markdown]
# Главный бухгалтер компании "Рога и копыта" случайно удалил ведомость с начисленной зарплатой. К счастью, у него сохранились расчётные листки всех сотрудников. Помогите по этим расчётным листкам восстановить зарплатную ведомость. Архив с расчётными листками доступен по ссылке https://stepik.org/media/attachments/lesson/245299/rogaikopyta.zip (вы можете скачать и распаковать его вручную или самостоятельно научиться делать это с помощью скрипта на Питоне).
#
# Ведомость должна содержать 1000 строк, в каждой строке должно быть указано ФИО сотрудника и, через пробел, его зарплата. Сотрудники должны быть упорядочены по алфавиту.

# %%
folder_path = 'rogaikopyta'  # Путь к папке

sheet_set = set()

for filename in os.listdir(folder_path):  # Итерируемся по файлам в папке
    file_path = os.path.join(folder_path, filename) # Создаем корректный путь к файлу
    if os.path.isfile(file_path) and filename.endswith('xlsx'):
        data = pd.ExcelFile(file_path)
        sheet_set.add(*data.sheet_names)
        break

sheet_set
# Out:
# {'Sheet'}

# %% [markdown]
# В каджом файле в папке 'rogaikopyta' находится только 1 лист с названием 'Sheet'

# %%
for filename in os.listdir(folder_path): 
    file_path = os.path.join(folder_path, filename) 
    if os.path.isfile(file_path) and filename.endswith('xlsx'):
        data = pd.read_excel(file_path, sheet_name='Sheet')
        break

data
# Out:
#   Расчетный лист              Unnamed: 1 Unnamed: 2  Unnamed: 3
# 0            ФИО  Львов Дмитрий Петрович  Начислено    100473.0
# 1    Организация     ООО "Рога и копыта"        NaN         NaN

# %%
name = data.iloc[0][1]
name
# Out:
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/781988732.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   name = data.iloc[0][1]
# 'Львов Дмитрий Петрович'

# %%
salary = int(data.iloc[0][3])
salary
# Out:
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/2000878198.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   salary = int(data.iloc[0][3])
# 100473

# %%
employees = []

for filename in os.listdir(folder_path): 
    file_path = os.path.join(folder_path, filename) 
    if os.path.isfile(file_path) and filename.endswith('xlsx'):
        data = pd.read_excel(file_path, sheet_name='Sheet')
        employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# Out:
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# ...
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))
# /var/folders/9r/8ct5hzls1f13fzpnb590x1s40000gn/T/ipykernel_36576/823913273.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   employees.append((data.iloc[0][1], int(data.iloc[0][3])))

# %%
employees
# Out:
# [('Львов Дмитрий Петрович', 100473),
#  ('Васильев Алексей Александрович', 112944),
#  ('Сидоров Дмитрий Александрович', 142365),
#  ('Алексеев Петр Львович', 59379),
#  ('Иванов Михаил Дмитриевич', 105958),
#  ('Петров Лев Александрович', 16868),
#  ('Александров Михаил Иванович', 194971),
#  ('Дмитриев Петр Львович', 179075),
#  ('Александров Александр Михайлович', 15649),
#  ('Львов Михаил Сидорович', 156248),
#  ('Васильев Сергей Дмитриевич', 86677),
#  ('Васильев Алексей Михайлович', 153668),
#  ('Петров Дмитрий Иванович', 166122),
#  ('Иванов Дмитрий Иванович', 74066),
#  ('Александров Василий Петрович', 62088),
#  ('Дмитриев Сидор Сергеевич', 133697),
#  ('Петров Иван Васильевич', 169243),
#  ('Сергеев Дмитрий Дмитриевич', 100988),
#  ('Александров Василий Иванович', 41592),
#  ('Иванов Михаил Михайлович', 182202),
#  ('Львов Иван Иванович', 161100),
#  ('Петров Сергей Михайлович', 61937),
#  ('Львов Алексей Львович', 114344),
#  ('Сергеев Сергей Петрович', 68109),
#  ('Львов Сидор Иванович', 17970),
#  ('Сергеев Василий Сидорович', 122132),
#  ('Сидоров Сидор Михайлович', 153252),
#  ('Сергеев Лев Петрович', 119059),
#  ('Львов Дмитрий Александрович', 161786),
#  ('Сидоров Алексей Сидорович', 176103),
#  ('Сидоров Александр Дмитриевич', 14323),
#  ('Васильев Сергей Васильевич', 79471),
#  ('Иванов Василий Львович', 131771),
#  ('Васильев Петр Александрович', 111617),
#  ('Львов Василий Александрович', 129760),
#  ('Сидоров Алексей Иванович', 192301),
#  ('Сергеев Дмитрий Иванович', 148421),
#  ('Дмитриев Дмитрий Александрович', 160046),
#  ('Дмитриев Лев Сергеевич', 139478),
#  ('Петров Александр Петрович', 26776),
#  ('Львов Сергей Михайлович', 44543),
#  ('Алексеев Василий Иванович', 143727),
#  ('Сидоров Лев Львович', 21626),
#  ('Васильев Сидор Алексеевич', 126066),
#  ('Иванов Василий Александрович', 123959),
#  ('Петров Василий Петрович', 105235),
#  ('Алексеев Василий Дмитриевич', 140358),
#  ('Александров Василий Алексеевич', 10140),
#  ('Алексеев Дмитрий Иванович', 62544),
#  ('Александров Алексей Петрович', 79898),
#  ('Александров Сергей Михайлович', 147692),
#  ('Дмитриев Петр Алексеевич', 128262),
#  ('Сидоров Василий Сидорович', 166497),
#  ('Александров Михаил Сергеевич', 143827),
#  ('Львов Иван Петрович', 192072),
#  ('Петров Петр Иванович', 130389),
#  ('Сергеев Сидор Петрович', 14335),
#  ('Васильев Александр Петрович', 16467),
#  ('Алексеев Михаил Васильевич', 183709),
#  ('Александров Сергей Иванович', 194472),
#  ('Михайлов Лев Дмитриевич', 104134),
#  ('Дмитриев Василий Сидорович', 86528),
#  ('Львов Александр Михайлович', 94897),
#  ('Михайлов Петр Иванович', 63073),
#  ('Алексеев Василий Петрович', 46752),
#  ('Михайлов Алексей Петрович', 192491),
#  ('Алексеев Лев Дмитриевич', 116906),
#  ('Иванов Александр Иванович', 66499),
#  ('Алексеев Александр Михайлович', 98408),
#  ('Александров Дмитрий Петрович', 56195),
#  ('Михайлов Лев Васильевич', 14284),
#  ('Иванов Петр Львович', 44110),
#  ('Петров Сергей Петрович', 16678),
#  ('Петров Алексей Сергеевич', 74849),
#  ('Петров Петр Алексеевич', 11021),
#  ('Алексеев Иван Львович', 199640),
#  ('Львов Александр Львович', 65119),
#  ('Сидоров Сидор Васильевич', 187825),
#  ('Алексеев Михаил Сергеевич', 83688),
#  ('Сидоров Иван Петрович', 166545),
#  ('Дмитриев Дмитрий Сергеевич', 186958),
#  ('Петров Василий Сидорович', 181034),
#  ('Сидоров Дмитрий Иванович', 193657),
#  ('Михайлов Сидор Львович', 152167),
#  ('Дмитриев Иван Михайлович', 78392),
#  ('Александров Александр Дмитриевич', 47073),
#  ('Петров Лев Петрович', 155604),
#  ('Васильев Лев Дмитриевич', 65351),
#  ('Дмитриев Иван Алексеевич', 190763),
#  ('Дмитриев Александр Алексеевич', 123287),
#  ('Иванов Лев Иванович', 165654),
#  ('Сидоров Петр Львович', 99825),
#  ('Иванов Сидор Иванович', 56359),
#  ('Иванов Сергей Сидорович', 187900),
#  ('Петров Алексей Иванович', 166053),
#  ('Алексеев Василий Васильевич', 28694),
#  ('Александров Алексей Дмитриевич', 101150),
#  ('Иванов Сергей Петрович', 181013),
#  ('Александров Лев Васильевич', 19369),
#  ('Сидоров Дмитрий Васильевич', 12105),
#  ('Сидоров Сергей Петрович', 33520),
#  ('Васильев Василий Сергеевич', 151401),
#  ('Петров Сергей Сидорович', 70639),
#  ('Иванов Петр Сергеевич', 94970),
#  ('Васильев Василий Александрович', 165497),
#  ('Дмитриев Александр Михайлович', 133500),
#  ('Львов Лев Львович', 199311),
#  ('Сидоров Михаил Петрович', 156497),
#  ('Сидоров Сидор Иванович', 107644),
#  ('Александров Дмитрий Иванович', 182487),
#  ('Алексеев Петр Михайлович', 199001),
#  ('Алексеев Лев Сидорович', 161366),
#  ('Львов Михаил Александрович', 96283),
#  ('Алексеев Петр Сергеевич', 43772),
#  ('Сергеев Лев Львович', 114858),
#  ('Петров Сергей Васильевич', 186958),
#  ('Васильев Василий Сидорович', 192361),
#  ('Дмитриев Алексей Сидорович', 154468),
#  ('Васильев Иван Иванович', 82010),
#  ('Сидоров Иван Сергеевич', 53393),
#  ('Алексеев Алексей Сергеевич', 154050),
#  ('Петров Сидор Львович', 16000),
#  ('Львов Иван Сидорович', 126655),
#  ('Сергеев Александр Алексеевич', 32662),
#  ('Сидоров Александр Васильевич', 42485),
#  ('Иванов Иван Сергеевич', 25228),
#  ('Сидоров Сергей Васильевич', 60355),
#  ('Дмитриев Дмитрий Иванович', 110876),
#  ('Михайлов Иван Сергеевич', 150527),
#  ('Сидоров Михаил Львович', 139226),
#  ('Иванов Лев Васильевич', 22830),
#  ('Михайлов Дмитрий Васильевич', 126332),
#  ('Иванов Сергей Алексеевич', 43604),
#  ('Сидоров Василий Александрович', 156364),
#  ('Александров Иван Львович', 23785),
#  ('Дмитриев Александр Сергеевич', 156757),
#  ('Михайлов Михаил Сергеевич', 28258),
#  ('Сергеев Сидор Васильевич', 130587),
#  ('Львов Александр Васильевич', 79784),
#  ('Иванов Иван Дмитриевич', 17764),
#  ('Алексеев Алексей Васильевич', 85860),
#  ('Сергеев Сергей Михайлович', 30502),
#  ('Сергеев Василий Петрович', 132823),
#  ('Алексеев Василий Александрович', 22940),
#  ('Александров Сергей Васильевич', 94215),
#  ('Васильев Алексей Сидорович', 17177),
#  ('Дмитриев Лев Сидорович', 190244),
#  ('Васильев Михаил Сергеевич', 35113),
#  ('Васильев Иван Михайлович', 23757),
#  ('Иванов Лев Александрович', 149183),
#  ('Дмитриев Алексей Петрович', 67604),
#  ('Михайлов Василий Васильевич', 110128),
#  ('Михайлов Василий Сидорович', 198918),
#  ('Сидоров Лев Сергеевич', 110377),
#  ('Петров Сергей Алексеевич', 148398),
#  ('Александров Лев Сидорович', 55533),
#  ('Михайлов Василий Дмитриевич', 111162),
#  ('Иванов Михаил Александрович', 49487),
#  ('Михайлов Иван Иванович', 67885),
#  ('Михайлов Василий Михайлович', 31983),
#  ('Сергеев Василий Васильевич', 70361),
#  ('Львов Иван Алексеевич', 189416),
#  ('Иванов Дмитрий Александрович', 84333),
#  ('Михайлов Михаил Петрович', 16804),
#  ('Александров Дмитрий Дмитриевич', 113707),
#  ('Сидоров Лев Сидорович', 83300),
#  ('Сергеев Михаил Александрович', 94882),
#  ('Дмитриев Иван Львович', 91038),
#  ('Михайлов Александр Сергеевич', 36766),
#  ('Михайлов Сергей Петрович', 139704),
#  ('Сергеев Петр Львович', 85019),
#  ('Васильев Александр Иванович', 49839),
#  ('Дмитриев Петр Сидорович', 128062),
#  ('Иванов Алексей Александрович', 119048),
#  ('Львов Лев Алексеевич', 17389),
#  ('Алексеев Василий Алексеевич', 51396),
#  ('Петров Михаил Васильевич', 140160),
#  ('Александров Василий Сидорович', 170531),
#  ('Львов Сергей Алексеевич', 13803),
#  ('Алексеев Иван Алексеевич', 39696),
#  ('Дмитриев Василий Михайлович', 197304),
#  ('Иванов Петр Михайлович', 169034),
#  ('Львов Петр Александрович', 144304),
#  ('Михайлов Алексей Алексеевич', 29938),
#  ('Львов Алексей Дмитриевич', 44372),
#  ('Петров Василий Александрович', 112363),
#  ('Алексеев Алексей Сидорович', 111822),
#  ('Александров Василий Васильевич', 51348),
#  ('Сидоров Дмитрий Петрович', 123937),
#  ('Дмитриев Лев Михайлович', 54722),
#  ('Сергеев Лев Сидорович', 99758),
#  ('Васильев Сергей Михайлович', 117383),
#  ('Петров Дмитрий Васильевич', 104795),
#  ('Дмитриев Сидор Михайлович', 165626),
#  ('Петров Дмитрий Петрович', 173613),
#  ('Сергеев Лев Алексеевич', 199286),
#  ('Петров Петр Львович', 48636),
#  ('Алексеев Сидор Михайлович', 50656),
#  ('Александров Иван Петрович', 42865),
#  ('Сидоров Петр Иванович', 141087),
#  ('Иванов Петр Иванович', 39860),
#  ('Алексеев Дмитрий Сидорович', 39159),
#  ('Васильев Иван Сидорович', 174043),
#  ('Васильев Дмитрий Сидорович', 13129),
#  ('Петров Сидор Васильевич', 176250),
#  ('Львов Сидор Петрович', 137211),
#  ('Сергеев Лев Михайлович', 182248),
#  ('Васильев Лев Михайлович', 82238),
#  ('Алексеев Михаил Петрович', 178414),
#  ('Сергеев Сидор Дмитриевич', 102580),
#  ('Львов Михаил Сергеевич', 155139),
#  ('Сидоров Сидор Львович', 93196),
#  ('Львов Василий Львович', 116020),
#  ('Львов Михаил Алексеевич', 147671),
#  ('Петров Сергей Иванович', 100175),
#  ('Сергеев Иван Львович', 43957),
#  ('Алексеев Сергей Львович', 74579),
#  ('Александров Алексей Сергеевич', 115746),
#  ('Дмитриев Сидор Сидорович', 54105),
#  ('Сидоров Василий Васильевич', 51036),
#  ('Александров Сидор Васильевич', 132050),
#  ('Сергеев Лев Сергеевич', 164855),
#  ('Сидоров Сергей Александрович', 132110),
#  ('Сергеев Сергей Дмитриевич', 182039),
#  ('Васильев Василий Дмитриевич', 65085),
#  ('Сидоров Дмитрий Сергеевич', 23237),
#  ('Дмитриев Иван Иванович', 113595),
#  ('Львов Сидор Алексеевич', 85555),
#  ('Петров Сидор Михайлович', 107478),
#  ('Петров Василий Иванович', 129895),
#  ('Михайлов Дмитрий Дмитриевич', 20585),
#  ('Львов Петр Петрович', 56915),
#  ('Михайлов Дмитрий Алексеевич', 82067),
#  ('Сергеев Михаил Дмитриевич', 99665),
#  ('Васильев Лев Васильевич', 41721),
#  ('Михайлов Дмитрий Петрович', 31527),
#  ('Михайлов Лев Сидорович', 153069),
#  ('Сидоров Александр Петрович', 66150),
#  ('Александров Петр Дмитриевич', 187677),
#  ('Сидоров Александр Сидорович', 98548),
#  ('Сергеев Сергей Сергеевич', 127779),
#  ('Сидоров Сергей Сидорович', 193932),
#  ('Иванов Михаил Сидорович', 97373),
#  ('Дмитриев Сидор Львович', 11623),
#  ('Алексеев Сидор Петрович', 117733),
#  ('Алексеев Алексей Львович', 58913),
#  ('Петров Лев Михайлович', 87694),
#  ('Алексеев Лев Иванович', 158605),
#  ('Михайлов Дмитрий Иванович', 139753),
#  ('Александров Василий Львович', 161129),
#  ('Петров Михаил Александрович', 157592),
#  ('Петров Александр Александрович', 177853),
#  ('Михайлов Сидор Васильевич', 138171),
#  ('Алексеев Василий Сидорович', 67455),
#  ('Петров Сергей Сергеевич', 106676),
#  ('Иванов Лев Алексеевич', 17116),
#  ('Сергеев Александр Иванович', 128256),
#  ('Васильев Сидор Дмитриевич', 185503),
#  ('Петров Сергей Львович', 181279),
#  ('Дмитриев Сергей Петрович', 168319),
#  ('Сергеев Дмитрий Львович', 47760),
#  ('Васильев Лев Петрович', 115366),
#  ('Сергеев Иван Александрович', 25317),
#  ('Александров Сергей Алексеевич', 54573),
#  ('Михайлов Лев Сергеевич', 94249),
#  ('Дмитриев Михаил Петрович', 112355),
#  ('Михайлов Иван Александрович', 192922),
#  ('Сидоров Александр Алексеевич', 172286),
#  ('Васильев Иван Васильевич', 195119),
#  ('Алексеев Дмитрий Сергеевич', 113490),
#  ('Сидоров Сергей Львович', 59678),
#  ('Михайлов Михаил Михайлович', 114059),
#  ('Львов Петр Сергеевич', 150891),
#  ('Львов Сергей Иванович', 68000),
#  ('Сидоров Михаил Михайлович', 142921),
#  ('Петров Сергей Дмитриевич', 82359),
#  ('Львов Сидор Сергеевич', 139781),
#  ('Алексеев Алексей Петрович', 118427),
#  ('Алексеев Сидор Иванович', 142139),
#  ('Петров Сидор Петрович', 10834),
#  ('Александров Сидор Петрович', 114620),
#  ('Васильев Петр Сергеевич', 75289),
#  ('Дмитриев Александр Иванович', 79946),
#  ('Алексеев Сергей Алексеевич', 73312),
#  ('Михайлов Лев Иванович', 127496),
#  ('Львов Петр Михайлович', 87407),
#  ('Петров Михаил Алексеевич', 121682),
#  ('Михайлов Василий Александрович', 75757),
#  ('Петров Михаил Львович', 82553),
#  ('Васильев Сергей Иванович', 135001),
#  ('Сергеев Петр Михайлович', 97003),
#  ('Дмитриев Иван Сергеевич', 114465),
#  ('Дмитриев Василий Александрович', 35045),
#  ('Иванов Алексей Львович', 84413),
#  ('Сергеев Сергей Васильевич', 181624),
#  ('Львов Иван Дмитриевич', 22493),
#  ('Львов Василий Михайлович', 119211),
#  ('Сидоров Дмитрий Дмитриевич', 76932),
#  ('Дмитриев Петр Сергеевич', 86822),
#  ('Сергеев Александр Сергеевич', 38085),
#  ('Михайлов Петр Дмитриевич', 107916),
#  ('Александров Александр Иванович', 98888),
#  ('Дмитриев Сидор Александрович', 58018),
#  ('Львов Александр Алексеевич', 142395),
#  ('Дмитриев Сергей Александрович', 92399),
#  ('Сидоров Александр Иванович', 126331),
#  ('Алексеев Сидор Сидорович', 183379),
#  ('Львов Лев Сергеевич', 89373),
#  ('Иванов Алексей Васильевич', 45001),
#  ('Петров Василий Михайлович', 13112),
#  ('Михайлов Александр Петрович', 121372),
#  ('Иванов Иван Петрович', 15008),
#  ('Алексеев Сидор Сергеевич', 62827),
#  ('Сидоров Сергей Дмитриевич', 71977),
#  ('Иванов Дмитрий Дмитриевич', 71650),
#  ('Сергеев Лев Васильевич', 35582),
#  ('Алексеев Сидор Васильевич', 114481),
#  ('Михайлов Дмитрий Михайлович', 89443),
#  ('Дмитриев Лев Дмитриевич', 98671),
#  ('Львов Сидор Васильевич', 107973),
#  ('Петров Александр Львович', 29023),
#  ('Васильев Иван Сергеевич', 163668),
#  ('Львов Иван Васильевич', 114862),
#  ('Дмитриев Дмитрий Алексеевич', 139668),
#  ('Петров Александр Сергеевич', 141110),
#  ('Александров Александр Петрович', 182105),
#  ('Львов Михаил Васильевич', 152677),
#  ('Сергеев Алексей Петрович', 137518),
#  ('Михайлов Михаил Васильевич', 198026),
#  ('Львов Петр Львович', 48175),
#  ('Иванов Лев Сергеевич', 80029),
#  ('Иванов Сергей Львович', 150878),
#  ('Петров Иван Иванович', 155294),
#  ('Васильев Иван Александрович', 85431),
#  ('Сидоров Петр Михайлович', 40895),
#  ('Львов Александр Иванович', 58137),
#  ('Алексеев Лев Сергеевич', 97822),
#  ('Петров Лев Васильевич', 140566),
#  ('Петров Иван Алексеевич', 173381),
#  ('Васильев Александр Алексеевич', 85891),
#  ('Сергеев Иван Иванович', 13907),
#  ('Сидоров Василий Алексеевич', 56518),
#  ('Львов Сергей Сидорович', 187440),
#  ('Алексеев Сергей Сидорович', 133119),
#  ('Васильев Петр Михайлович', 173845),
#  ('Петров Петр Сергеевич', 14278),
#  ('Сидоров Василий Михайлович', 149096),
#  ('Алексеев Александр Иванович', 112956),
#  ('Александров Сидор Дмитриевич', 161591),
#  ('Сергеев Александр Васильевич', 124311),
#  ('Сергеев Иван Петрович', 54967),
#  ('Сидоров Лев Михайлович', 102670),
#  ('Дмитриев Лев Алексеевич', 33539),
#  ('Петров Петр Васильевич', 164844),
#  ('Алексеев Дмитрий Львович', 153225),
#  ('Иванов Лев Львович', 132223),
#  ('Александров Лев Михайлович', 126449),
#  ('Васильев Сидор Михайлович', 105178),
#  ('Алексеев Василий Львович', 86478),
#  ('Сергеев Александр Петрович', 199386),
#  ('Алексеев Михаил Сидорович', 182931),
#  ('Львов Александр Сидорович', 149787),
#  ('Дмитриев Алексей Васильевич', 194934),
#  ('Михайлов Сергей Алексеевич', 93757),
#  ('Львов Дмитрий Сергеевич', 19335),
#  ('Михайлов Сидор Дмитриевич', 24902),
#  ('Васильев Сидор Иванович', 148952),
#  ('Васильев Михаил Дмитриевич', 181729),
#  ('Иванов Сергей Михайлович', 140953),
#  ('Михайлов Александр Иванович', 42543),
#  ('Иванов Иван Алексеевич', 165304),
#  ('Михайлов Александр Дмитриевич', 193661),
#  ('Александров Иван Сергеевич', 84836),
#  ('Дмитриев Дмитрий Львович', 101874),
#  ('Иванов Сидор Дмитриевич', 190361),
#  ('Александров Петр Львович', 78514),
#  ('Дмитриев Алексей Дмитриевич', 111783),
#  ('Иванов Иван Александрович', 174803),
#  ('Львов Михаил Дмитриевич', 89810),
#  ('Петров Александр Иванович', 58276),
#  ('Алексеев Лев Васильевич', 95811),
#  ('Сидоров Петр Сергеевич', 142875),
#  ('Львов Дмитрий Дмитриевич', 76612),
#  ('Львов Сидор Сидорович', 62946),
#  ('Васильев Сидор Александрович', 130756),
#  ('Иванов Сидор Алексеевич', 109132),
#  ('Львов Сидор Александрович', 86091),
#  ('Сидоров Дмитрий Львович', 67344),
#  ('Сидоров Алексей Михайлович', 167697),
#  ('Сидоров Сидор Дмитриевич', 27705),
#  ('Иванов Сергей Дмитриевич', 136447),
#  ('Алексеев Лев Александрович', 199676),
#  ('Петров Михаил Иванович', 35953),
#  ('Иванов Лев Михайлович', 77978),
#  ('Иванов Александр Александрович', 93898),
#  ('Васильев Александр Александрович', 76921),
#  ('Сергеев Василий Михайлович', 197250),
#  ('Сергеев Иван Алексеевич', 62575),
#  ('Сидоров Петр Сидорович', 62720),
#  ('Львов Сергей Дмитриевич', 38382),
#  ('Алексеев Сидор Алексеевич', 66955),
#  ('Михайлов Михаил Иванович', 112613),
#  ('Петров Алексей Васильевич', 145737),
#  ('Михайлов Сергей Михайлович', 192388),
#  ('Сергеев Алексей Сидорович', 130415),
#  ('Васильев Алексей Дмитриевич', 109082),
#  ('Иванов Иван Васильевич', 77516),
#  ('Иванов Петр Васильевич', 161293),
#  ('Алексеев Александр Львович', 194943),
#  ('Васильев Алексей Львович', 165470),
#  ('Александров Сергей Сергеевич', 173393),
#  ('Александров Василий Михайлович', 193291),
#  ('Михайлов Сергей Васильевич', 177263),
#  ('Петров Сидор Сергеевич', 81767),
#  ('Алексеев Лев Алексеевич', 180073),
#  ('Михайлов Сидор Михайлович', 159830),
#  ('Дмитриев Сергей Дмитриевич', 127129),
#  ('Сидоров Михаил Алексеевич', 73301),
#  ('Михайлов Сергей Сергеевич', 197175),
#  ('Михайлов Александр Васильевич', 106788),
#  ('Сидоров Дмитрий Алексеевич', 106754),
#  ('Сергеев Петр Дмитриевич', 175373),
#  ('Александров Сидор Сергеевич', 96009),
#  ('Александров Иван Алексеевич', 50178),
#  ('Иванов Дмитрий Михайлович', 73859),
#  ('Иванов Михаил Львович', 194604),
#  ('Иванов Петр Дмитриевич', 70986),
#  ('Дмитриев Василий Алексеевич', 69019),
#  ('Дмитриев Петр Михайлович', 40839),
#  ('Васильев Петр Алексеевич', 125382),
#  ('Алексеев Михаил Алексеевич', 145639),
#  ('Васильев Лев Александрович', 178181),
#  ('Петров Александр Алексеевич', 184355),
#  ('Дмитриев Иван Сидорович', 95342),
#  ('Александров Иван Васильевич', 179724),
#  ('Иванов Сидор Сидорович', 195686),
#  ('Васильев Алексей Сергеевич', 99798),
#  ('Львов Лев Иванович', 190843),
#  ('Львов Александр Петрович', 34750),
#  ('Алексеев Дмитрий Дмитриевич', 69961),
#  ('Михайлов Дмитрий Львович', 136764),
#  ('Дмитриев Михаил Алексеевич', 71258),
#  ('Михайлов Сергей Иванович', 67020),
#  ('Михайлов Иван Михайлович', 124394),
#  ('Львов Михаил Иванович', 99059),
#  ('Васильев Петр Львович', 55179),
#  ('Михайлов Александр Алексеевич', 15769),
#  ('Алексеев Лев Михайлович', 144596),
#  ('Сидоров Василий Дмитриевич', 185872),
#  ('Михайлов Дмитрий Сидорович', 157929),
#  ('Дмитриев Сидор Васильевич', 12640),
#  ('Дмитриев Сергей Иванович', 72300),
#  ('Алексеев Алексей Алексеевич', 150997),
#  ('Иванов Алексей Алексеевич', 28396),
#  ('Сидоров Петр Петрович', 37846),
#  ('Сергеев Михаил Львович', 198693),
#  ('Васильев Петр Петрович', 120771),
#  ('Сергеев Иван Михайлович', 14872),
#  ('Сидоров Алексей Сергеевич', 170541),
#  ('Сидоров Иван Васильевич', 15782),
#  ('Васильев Василий Алексеевич', 155525),
#  ('Алексеев Михаил Александрович', 106762),
#  ('Сидоров Сергей Алексеевич', 157701),
#  ('Васильев Сергей Львович', 157921),
#  ('Васильев Лев Львович', 44708),
#  ('Дмитриев Иван Дмитриевич', 195397),
#  ('Александров Сергей Александрович', 167078),
#  ('Иванов Лев Петрович', 129582),
#  ('Петров Иван Сергеевич', 33491),
#  ('Васильев Дмитрий Иванович', 123809),
#  ('Алексеев Сидор Дмитриевич', 145855),
#  ('Дмитриев Петр Александрович', 153785),
#  ('Александров Петр Александрович', 143212),
#  ('Львов Сергей Сергеевич', 192412),
#  ('Львов Александр Сергеевич', 163580),
#  ('Михайлов Михаил Дмитриевич', 173583),
#  ('Михайлов Сидор Сидорович', 84634),
#  ('Алексеев Сидор Александрович', 12453),
#  ('Александров Дмитрий Сидорович', 26131),
#  ('Сидоров Дмитрий Михайлович', 143940),
#  ('Дмитриев Василий Петрович', 55725),
#  ('Алексеев Петр Дмитриевич', 100082),
#  ('Львов Лев Сидорович', 31628),
#  ('Дмитриев Лев Иванович', 147662),
#  ('Петров Александр Сидорович', 192491),
#  ('Иванов Петр Александрович', 181437),
#  ('Александров Василий Сергеевич', 28040),
#  ('Дмитриев Сидор Петрович', 74167),
#  ('Сидоров Алексей Алексеевич', 146560),
#  ('Михайлов Алексей Александрович', 165619),
#  ('Алексеев Сергей Иванович', 109802),
#  ('Сергеев Василий Иванович', 17757),
#  ('Васильев Михаил Иванович', 120718),
#  ('Александров Дмитрий Алексеевич', 168375),
#  ('Алексеев Иван Михайлович', 39435),
#  ('Львов Василий Алексеевич', 93967),
#  ('Алексеев Василий Сергеевич', 153033),
#  ('Петров Сидор Дмитриевич', 40311),
#  ('Александров Дмитрий Михайлович', 108259),
#  ('Алексеев Иван Сергеевич', 117078),
#  ('Михайлов Петр Сергеевич', 32889),
#  ('Алексеев Александр Алексеевич', 182964),
#  ('Михайлов Петр Сидорович', 103365),
#  ('Александров Лев Петрович', 69261),
#  ('Сидоров Петр Алексеевич', 153590),
#  ('Михайлов Алексей Васильевич', 142869),
#  ('Иванов Сидор Васильевич', 183140),
#  ('Львов Лев Петрович', 67875),
#  ('Львов Сергей Львович', 63066),
#  ('Сергеев Дмитрий Петрович', 70543),
#  ('Александров Алексей Александрович', 127967),
#  ('Сидоров Лев Петрович', 125859),
#  ('Сидоров Иван Алексеевич', 92899),
#  ('Петров Василий Алексеевич', 181938),
#  ('Петров Сидор Иванович', 38643),
#  ('Петров Алексей Петрович', 98470),
#  ('Сергеев Сидор Иванович', 88867),
#  ('Александров Михаил Михайлович', 155441),
#  ('Сидоров Иван Иванович', 108948),
#  ('Александров Алексей Львович', 159123),
#  ('Александров Иван Михайлович', 126469),
#  ('Львов Алексей Александрович', 149262),
#  ('Сергеев Лев Дмитриевич', 32266),
#  ('Иванов Александр Львович', 154976),
#  ('Петров Михаил Петрович', 192170),
#  ('Сидоров Михаил Александрович', 49259),
#  ('Сергеев Алексей Иванович', 114165),
#  ('Алексеев Дмитрий Александрович', 57950),
#  ('Дмитриев Дмитрий Михайлович', 115636),
#  ('Сергеев Михаил Петрович', 146962),
#  ('Дмитриев Михаил Александрович', 183953),
#  ('Александров Василий Александрович', 176610),
#  ('Сергеев Василий Алексеевич', 124161),
#  ('Сергеев Петр Сидорович', 108533),
#  ('Дмитриев Алексей Александрович', 184589),
#  ('Дмитриев Сергей Алексеевич', 54244),
#  ('Александров Алексей Алексеевич', 94641),
#  ('Михайлов Сидор Сергеевич', 59994),
#  ('Петров Алексей Алексеевич', 156749),
#  ('Дмитриев Дмитрий Петрович', 159537),
#  ('Дмитриев Михаил Васильевич', 126439),
#  ('Михайлов Дмитрий Сергеевич', 171608),
#  ('Сидоров Алексей Васильевич', 113613),
#  ('Иванов Дмитрий Петрович', 173286),
#  ('Сидоров Алексей Петрович', 166532),
#  ('Иванов Александр Сидорович', 89358),
#  ('Васильев Лев Сергеевич', 27501),
#  ('Александров Александр Алексеевич', 111877),
#  ('Иванов Иван Сидорович', 43098),
#  ('Сидоров Лев Васильевич', 91388),
#  ('Васильев Александр Михайлович', 171360),
#  ('Сергеев Сидор Александрович', 123896),
#  ('Иванов Михаил Сергеевич', 101796),
#  ('Михайлов Михаил Алексеевич', 42629),
#  ('Сергеев Александр Львович', 76432),
#  ('Михайлов Лев Александрович', 110883),
#  ('Петров Дмитрий Сергеевич', 72744),
#  ('Иванов Дмитрий Сергеевич', 107799),
#  ('Сидоров Михаил Иванович', 22048),
#  ('Михайлов Василий Сергеевич', 14955),
#  ('Васильев Сидор Сидорович', 125855),
#  ('Александров Василий Дмитриевич', 193630),
#  ('Дмитриев Сергей Михайлович', 184081),
#  ('Дмитриев Сергей Сергеевич', 116375),
#  ('Васильев Василий Иванович', 81275),
#  ('Львов Иван Михайлович', 28092),
#  ('Дмитриев Михаил Львович', 111575),
#  ('Сергеев Петр Иванович', 57456),
#  ('Львов Дмитрий Михайлович', 124136),
#  ('Александров Сергей Львович', 46653),
#  ('Сергеев Василий Львович', 121348),
#  ('Александров Михаил Александрович', 184373),
#  ('Сергеев Дмитрий Сергеевич', 27876),
#  ('Сидоров Александр Львович', 161060),
#  ('Михайлов Иван Дмитриевич', 49557),
#  ('Сергеев Алексей Сергеевич', 134096),
#  ('Алексеев Алексей Михайлович', 192892),
#  ('Александров Михаил Львович', 58615),
#  ('Петров Александр Дмитриевич', 75794),
#  ('Петров Сидор Алексеевич', 27358),
#  ('Михайлов Петр Александрович', 95816),
#  ('Иванов Сидор Львович', 113838),
#  ('Михайлов Петр Львович', 123325),
#  ('Васильев Сергей Александрович', 175215),
#  ('Сергеев Александр Дмитриевич', 75256),
#  ('Александров Сидор Алексеевич', 16745),
#  ('Петров Лев Львович', 28125),
#  ('Львов Алексей Иванович', 127050),
#  ('Сидоров Василий Львович', 44233),
#  ('Александров Сидор Михайлович', 25275),
#  ('Сергеев Сидор Львович', 13462),
#  ('Иванов Дмитрий Алексеевич', 158117),
#  ('Сергеев Александр Александрович', 99886),
#  ('Сергеев Иван Дмитриевич', 191013),
#  ('Сергеев Дмитрий Сидорович', 160851),
#  ('Михайлов Петр Васильевич', 77589),
#  ('Петров Александр Михайлович', 164270),
#  ('Дмитриев Лев Львович', 10266),
#  ('Александров Алексей Иванович', 108854),
#  ('Иванов Михаил Иванович', 174725),
#  ('Петров Василий Дмитриевич', 111563),
#  ('Александров Сидор Львович', 100987),
#  ('Дмитриев Сидор Иванович', 66365),
#  ('Львов Иван Львович', 118436),
#  ('Дмитриев Дмитрий Сидорович', 123014),
#  ('Александров Лев Львович', 61734),
#  ('Иванов Сергей Иванович', 59606),
#  ('Михайлов Сергей Дмитриевич', 104165),
#  ('Сидоров Василий Сергеевич', 79348),
#  ('Алексеев Михаил Львович', 23892),
#  ('Иванов Петр Петрович', 118702),
#  ('Иванов Иван Михайлович', 109875),
#  ('Львов Алексей Алексеевич', 106678),
#  ('Алексеев Иван Васильевич', 36877),
#  ('Дмитриев Дмитрий Дмитриевич', 37892),
#  ('Иванов Сидор Александрович', 150005),
#  ('Петров Иван Дмитриевич', 23546),
#  ('Михайлов Алексей Дмитриевич', 66593),
#  ('Васильев Сидор Васильевич', 162147),
#  ('Петров Сергей Александрович', 108703),
#  ('Сергеев Алексей Дмитриевич', 19496),
#  ('Сергеев Сергей Иванович', 181518),
#  ('Васильев Михаил Васильевич', 109562),
#  ('Львов Лев Васильевич', 128871),
#  ('Иванов Алексей Дмитриевич', 194106),
#  ('Васильев Алексей Васильевич', 77652),
#  ('Петров Алексей Александрович', 89665),
#  ('Сидоров Алексей Александрович', 160582),
#  ('Сергеев Иван Сидорович', 138242),
#  ('Львов Алексей Сергеевич', 87644),
#  ('Иванов Михаил Петрович', 145867),
#  ('Александров Петр Васильевич', 146522),
#  ('Михайлов Алексей Михайлович', 33304),
#  ('Львов Иван Сергеевич', 115282),
#  ('Дмитриев Александр Львович', 43690),
#  ('Сергеев Михаил Иванович', 41495),
#  ('Васильев Сергей Петрович', 38510),
#  ('Петров Иван Сидорович', 84790),
#  ('Сергеев Петр Петрович', 19389),
#  ('Алексеев Сергей Михайлович', 173774),
#  ('Петров Алексей Дмитриевич', 165164),
#  ('Александров Михаил Васильевич', 87131),
#  ('Александров Лев Александрович', 135047),
#  ('Алексеев Петр Алексеевич', 16709),
#  ('Александров Петр Иванович', 147868),
#  ('Алексеев Сергей Дмитриевич', 87622),
#  ('Алексеев Иван Петрович', 39788),
#  ('Львов Василий Иванович', 11028),
#  ('Алексеев Александр Дмитриевич', 113875),
#  ('Александров Алексей Михайлович', 87990),
#  ('Иванов Александр Петрович', 183978),
#  ('Иванов Сергей Александрович', 112526),
#  ('Иванов Василий Дмитриевич', 164573),
#  ('Сидоров Александр Сергеевич', 106443),
#  ('Дмитриев Михаил Михайлович', 30022),
#  ('Алексеев Иван Сидорович', 32267),
#  ('Иванов Иван Иванович', 42721),
#  ('Александров Лев Алексеевич', 96521),
#  ('Иванов Алексей Сидорович', 27043),
#  ('Сидоров Сергей Сергеевич', 52289),
#  ('Сергеев Иван Сергеевич', 174899),
#  ('Михайлов Алексей Львович', 191527),
#  ('Сидоров Петр Дмитриевич', 153598),
#  ('Львов Лев Александрович', 71216),
#  ('Сидоров Сергей Михайлович', 18146),
#  ('Алексеев Дмитрий Васильевич', 139592),
#  ('Львов Александр Дмитриевич', 55678),
#  ('Александров Лев Дмитриевич', 96632),
#  ('Дмитриев Петр Дмитриевич', 162750),
#  ('Сидоров Александр Александрович', 73132),
#  ('Дмитриев Александр Александрович', 54374),
#  ('Васильев Петр Иванович', 24199),
#  ('Дмитриев Лев Васильевич', 111590),
#  ('Петров Лев Иванович', 144684),
#  ('Петров Петр Александрович', 183919),
#  ('Иванов Лев Дмитриевич', 179398),
#  ('Михайлов Иван Львович', 187280),
#  ('Александров Дмитрий Васильевич', 126134),
#  ('Васильев Михаил Львович', 45508),
#  ('Петров Петр Дмитриевич', 102914),
#  ('Александров Иван Сидорович', 79879),
#  ('Сидоров Александр Михайлович', 113003),
#  ('Васильев Василий Львович', 132628),
#  ('Сидоров Лев Алексеевич', 176862),
#  ('Львов Алексей Сидорович', 33669),
#  ('Львов Петр Дмитриевич', 50286),
#  ('Сергеев Петр Сергеевич', 138255),
#  ('Александров Петр Михайлович', 189119),
#  ('Львов Михаил Львович', 177726),
#  ('Иванов Михаил Алексеевич', 174203),
#  ('Алексеев Сергей Васильевич', 173886),
#  ('Петров Василий Сергеевич', 68759),
#  ('Михайлов Михаил Александрович', 21941),
#  ('Львов Дмитрий Сидорович', 187468),
#  ('Васильев Сергей Сергеевич', 136829),
#  ('Сидоров Лев Дмитриевич', 36979),
#  ('Александров Лев Иванович', 63673),
#  ('Михайлов Петр Петрович', 104565),
#  ('Михайлов Иван Алексеевич', 164224),
#  ('Дмитриев Сергей Васильевич', 157978),
#  ('Петров Сидор Сидорович', 193771),
#  ('Алексеев Сергей Сергеевич', 171834),
#  ('Иванов Алексей Михайлович', 126754),
#  ('Иванов Александр Васильевич', 196624),
#  ('Львов Петр Алексеевич', 52945),
#  ('Алексеев Александр Александрович', 106923),
#  ('Иванов Сергей Васильевич', 42110),
#  ('Сергеев Сергей Алексеевич', 175654),
#  ('Алексеев Михаил Дмитриевич', 164160),
#  ('Александров Александр Александрович', 19279),
#  ('Львов Дмитрий Васильевич', 162936),
#  ('Иванов Сидор Петрович', 143403),
#  ('Сергеев Сидор Сергеевич', 96425),
#  ('Сергеев Александр Михайлович', 154595),
#  ('Васильев Михаил Петрович', 144598),
#  ('Иванов Василий Иванович', 129691),
#  ('Петров Лев Алексеевич', 63488),
#  ('Петров Иван Михайлович', 170987),
#  ('Александров Михаил Алексеевич', 83305),
#  ('Александров Иван Иванович', 45837),
#  ('Иванов Александр Михайлович', 161566),
#  ('Петров Лев Сидорович', 172572),
#  ('Алексеев Михаил Михайлович', 173477),
#  ('Иванов Василий Васильевич', 65951),
#  ('Сидоров Михаил Васильевич', 166155),
#  ('Дмитриев Василий Дмитриевич', 49661),
#  ('Дмитриев Александр Сидорович', 99422),
#  ('Петров Алексей Львович', 176937),
#  ('Михайлов Иван Васильевич', 76058),
#  ('Сидоров Сидор Сидорович', 130081),
#  ('Сергеев Василий Сергеевич', 92101),
#  ('Алексеев Петр Петрович', 76485),
#  ('Михайлов Алексей Сергеевич', 140814),
#  ('Михайлов Сергей Сидорович', 119015),
#  ('Сидоров Сидор Сергеевич', 108788),
#  ('Александров Михаил Сидорович', 198240),
#  ('Васильев Василий Петрович', 80972),
#  ('Васильев Иван Львович', 189814),
#  ('Михайлов Лев Петрович', 194116),
#  ('Сидоров Дмитрий Сидорович', 75261),
#  ('Петров Дмитрий Дмитриевич', 63179),
#  ('Дмитриев Петр Петрович', 127484),
#  ('Алексеев Петр Васильевич', 19729),
#  ('Александров Сергей Петрович', 29540),
#  ('Александров Александр Львович', 148442),
#  ('Петров Алексей Михайлович', 123300),
#  ('Алексеев Александр Сергеевич', 197277),
#  ('Дмитриев Сергей Сидорович', 133234),
#  ('Сидоров Иван Сидорович', 148506),
#  ('Петров Дмитрий Александрович', 15209),
#  ('Алексеев Лев Петрович', 76675),
#  ('Дмитриев Василий Сергеевич', 129165),
#  ('Александров Дмитрий Сергеевич', 28668),
#  ('Петров Дмитрий Михайлович', 31272),
#  ('Петров Дмитрий Сидорович', 148179),
#  ('Алексеев Иван Иванович', 17097),
#  ('Дмитриев Петр Иванович', 132849),
#  ('Дмитриев Василий Васильевич', 92812),
#  ('Петров Иван Петрович', 166463),
#  ('Алексеев Александр Сидорович', 20058),
#  ('Сергеев Михаил Сидорович', 62553),
#  ('Львов Михаил Петрович', 114683),
#  ('Иванов Василий Михайлович', 173011),
#  ('Сергеев Алексей Васильевич', 28543),
#  ('Сидоров Сидор Алексеевич', 76605),
#  ('Сидоров Петр Александрович', 39828),
#  ('Львов Сидор Дмитриевич', 196459),
#  ('Львов Дмитрий Иванович', 148082),
#  ('Алексеев Василий Михайлович', 11098),
#  ('Иванов Василий Петрович', 120068),
#  ('Алексеев Петр Иванович', 73255),
#  ('Сидоров Иван Михайлович', 39126),
#  ('Иванов Дмитрий Васильевич', 50803),
#  ('Алексеев Сергей Петрович', 93384),
#  ('Васильев Петр Сидорович', 59636),
#  ('Васильев Дмитрий Алексеевич', 89483),
#  ('Львов Василий Васильевич', 66549),
#  ('Дмитриев Сергей Львович', 65012),
#  ('Васильев Дмитрий Дмитриевич', 19782),
#  ('Львов Сидор Львович', 91112),
#  ('Сидоров Михаил Сергеевич', 22263),
#  ('Петров Дмитрий Львович', 18442),
#  ('Иванов Алексей Сергеевич', 93510),
#  ('Сергеев Сидор Сидорович', 167482),
#  ('Васильев Иван Алексеевич', 98620),
#  ('Васильев Александр Сергеевич', 136914),
#  ('Сидоров Иван Александрович', 74017),
#  ('Львов Алексей Петрович', 73176),
#  ('Дмитриев Алексей Михайлович', 166859),
#  ('Александров Александр Сидорович', 167797),
#  ('Иванов Александр Дмитриевич', 124877),
#  ('Александров Дмитрий Александрович', 128011),
#  ('Васильев Сидор Львович', 105202),
#  ('Дмитриев Василий Львович', 160382),
#  ('Михайлов Лев Алексеевич', 135423),
#  ('Васильев Лев Иванович', 133239),
#  ('Львов Петр Иванович', 173375),
#  ('Васильев Петр Васильевич', 163579),
#  ('Сергеев Лев Александрович', 177407),
#  ('Иванов Василий Сидорович', 61700),
#  ('Дмитриев Алексей Львович', 51631),
#  ('Сидоров Алексей Львович', 184023),
#  ('Сергеев Василий Александрович', 102873),
#  ('Сергеев Иван Васильевич', 54076),
#  ('Васильев Василий Михайлович', 171091),
#  ('Сидоров Михаил Дмитриевич', 146055),
#  ('Алексеев Александр Петрович', 133119),
#  ('Дмитриев Алексей Сергеевич', 50071),
#  ('Михайлов Алексей Иванович', 190978),
#  ('Александров Петр Сидорович', 87848),
#  ('Михайлов Александр Александрович', 31515),
#  ('Львов Сергей Петрович', 183061),
#  ('Львов Лев Михайлович', 92355),
#  ('Васильев Михаил Алексеевич', 177502),
#  ('Михайлов Василий Алексеевич', 153823),
#  ('Александров Лев Сергеевич', 52193),
#  ('Петров Михаил Михайлович', 67169),
#  ('Львов Сергей Васильевич', 131681),
#  ('Сергеев Сидор Михайлович', 189156),
#  ('Михайлов Сидор Петрович', 105201),
#  ('Васильев Михаил Александрович', 139527),
#  ('Михайлов Сергей Александрович', 131755),
#  ('Львов Василий Сергеевич', 178931),
#  ('Сидоров Василий Петрович', 90299),
#  ('Иванов Алексей Иванович', 139446),
#  ('Васильев Лев Сидорович', 79308),
#  ('Алексеев Дмитрий Петрович', 198205),
#  ('Александров Сидор Александрович', 180193),
#  ('Петров Александр Васильевич', 181145),
#  ('Михайлов Александр Сидорович', 155657),
#  ('Михайлов Александр Михайлович', 23442),
#  ('Сергеев Алексей Михайлович', 75721),
#  ('Васильев Сидор Сергеевич', 182990),
#  ('Дмитриев Василий Иванович', 171703),
#  ('Сидоров Петр Васильевич', 108453),
#  ('Петров Дмитрий Алексеевич', 60473),
#  ('Львов Василий Сидорович', 64343),
#  ('Иванов Сидор Михайлович', 165403),
#  ('Сергеев Василий Дмитриевич', 163141),
#  ('Сидоров Лев Иванович', 174056),
#  ('Дмитриев Сидор Алексеевич', 147466),
#  ('Васильев Василий Васильевич', 70846),
#  ('Львов Александр Александрович', 54517),
#  ('Иванов Лев Сидорович', 54032),
#  ('Михайлов Василий Петрович', 63435),
#  ('Алексеев Алексей Иванович', 17757),
#  ('Дмитриев Александр Петрович', 58947),
#  ('Александров Алексей Сидорович', 102474),
#  ('Сергеев Лев Иванович', 198698),
#  ('Васильев Петр Дмитриевич', 58286),
#  ('Иванов Петр Сидорович', 91925),
#  ('Васильев Дмитрий Петрович', 21042),
#  ('Сергеев Сергей Александрович', 54525),
#  ('Алексеев Дмитрий Алексеевич', 130818),
#  ('Иванов Александр Алексеевич', 175060),
#  ('Михайлов Лев Львович', 17382),
#  ('Дмитриев Петр Васильевич', 60957),
#  ('Львов Дмитрий Львович', 154654),
#  ('Михайлов Сергей Львович', 28948),
#  ('Васильев Алексей Алексеевич', 38685),
#  ('Васильев Михаил Михайлович', 183206),
#  ('Петров Лев Дмитриевич', 49464),
#  ('Дмитриев Михаил Сидорович', 137511),
#  ('Михайлов Сидор Алексеевич', 145237),
#  ('Дмитриев Михаил Сергеевич', 199709),
#  ('Иванов Дмитрий Львович', 22041),
#  ('Васильев Иван Дмитриевич', 12416),
#  ('Иванов Петр Алексеевич', 25177),
#  ('Иванов Алексей Петрович', 72559),
#  ('Петров Петр Михайлович', 189861),
#  ('Васильев Алексей Иванович', 179258),
#  ('Дмитриев Лев Петрович', 138419),
#  ('Васильев Михаил Сидорович', 32827),
#  ('Васильев Иван Петрович', 162751),
#  ('Алексеев Михаил Иванович', 36543),
#  ('Васильев Александр Сидорович', 120751),
#  ('Александров Сидор Сидорович', 19927),
#  ('Алексеев Алексей Дмитриевич', 69636),
#  ('Львов Петр Сидорович', 58242),
#  ('Алексеев Иван Дмитриевич', 140673),
#  ('Алексеев Дмитрий Михайлович', 88913),
#  ('Васильев Дмитрий Сергеевич', 156945),
#  ('Петров Петр Петрович', 176824),
#  ('Алексеев Петр Сидорович', 108651),
#  ('Иванов Дмитрий Сидорович', 73970),
#  ('Александров Сергей Сидорович', 81625),
#  ('Сидоров Алексей Дмитриевич', 103644),
#  ('Сергеев Петр Александрович', 27655),
#  ('Михайлов Петр Михайлович', 123770),
#  ('Сидоров Сидор Петрович', 46026),
#  ('Дмитриев Александр Дмитриевич', 155451),
#  ('Александров Михаил Петрович', 49435),
#  ('Васильев Сидор Петрович', 123082),
#  ('Львов Василий Дмитриевич', 194288),
#  ('Петров Михаил Сидорович', 115601),
#  ('Михайлов Петр Алексеевич', 71768),
#  ('Александров Петр Петрович', 143475),
#  ('Сергеев Михаил Васильевич', 126743),
#  ('Иванов Василий Сергеевич', 177381),
#  ('Дмитриев Михаил Дмитриевич', 16707),
#  ('Михайлов Иван Петрович', 173606),
#  ('Дмитриев Алексей Алексеевич', 183574),
#  ('Михайлов Алексей Сидорович', 192984),
#  ('Петров Лев Сергеевич', 193927),
#  ('Александров Александр Васильевич', 121425),
#  ('Сергеев Михаил Алексеевич', 131950),
#  ('Сидоров Иван Дмитриевич', 98021),
#  ('Львов Василий Петрович', 95553),
#  ('Михайлов Иван Сидорович', 65961),
#  ('Сергеев Александр Сидорович', 166447),
#  ('Александров Иван Александрович', 118890),
#  ('Львов Алексей Васильевич', 78634),
#  ('Васильев Алексей Петрович', 43956),
#  ('Сидоров Сидор Александрович', 195189),
#  ('Васильев Александр Дмитриевич', 163444),
#  ('Петров Петр Сидорович', 168047),
#  ('Васильев Дмитрий Михайлович', 136077),
#  ('Петров Василий Васильевич', 123594),
#  ('Сергеев Петр Васильевич', 110809),
#  ('Львов Алексей Михайлович', 81987),
#  ('Иванов Василий Алексеевич', 64500),
#  ('Петров Сидор Александрович', 16198),
#  ('Алексеев Сергей Александрович', 41630),
#  ('Сидоров Лев Александрович', 153404),
#  ('Васильев Александр Львович', 60155),
#  ('Сергеев Дмитрий Васильевич', 22012),
#  ('Львов Михаил Михайлович', 161987),
#  ('Сергеев Сергей Сидорович', 154332),
#  ('Михайлов Сидор Иванович', 35588),
#  ('Дмитриев Дмитрий Васильевич', 33490),
#  ('Сергеев Михаил Михайлович', 197558),
